# %% [markdown]
# <a href="https://colab.research.google.com/github/garvitbhardwajj/new_repo/blob/main/EDA_of_air_bnb_booking_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA -Playstore app review analysis
# ##### **Contribution**    - Individual
# **Name**- Garvit Bhardwaj
# email id- garvitbhardwaj25@gmail.com

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **discover insights like-trends,corelations,inefficencies etc**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# 1. **Identfying high revenue places and high volume booking places to increase revenue**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
df=pd.read_csv('/content/drive/MyDrive/Almabetter/Airbnb NYC 2019 (1).csv')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f'Dataset has {df.shape[0]} rows and {df.shape[1]} columns')
# Out:
# Dataset has 48895 rows and 16 columns

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
no_of_duplicates=df.duplicated(keep=False).sum()
print(no_of_duplicates)
# there are zero duplicates rows in this dataframe
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isna().sum())

# 16 missing names
# 21 missing host names
# 10,000+ missing reviews
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ### Why name or host id is missing?
#
# As they are very small part of the data and removing them doesn't affect the  quality of data.
#
#
# **we will remove rows with missing values in name and host_id columns**

# %%
# Visualizing the missing values
df.dropna(subset=['name','host_name'],inplace=True)
df.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10037
# reviews_per_month                 10037
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.shape
# Out:
# (48858, 16)

# %% [markdown]
# ### Handling missng values in last_review and reviews_per_month
#
# Why there are missng values in last review or reviews per month?
#
#
# we can assume that-
#
# 1. property has not been booked even a single time becuase-
#     - they are new properties and no one had stayed at them.
#     - they are old properties but no one had stayed at them
# 2.  properties that has been visited but no one has posted a review after their visit.
#
#
# ---
#
#
# How much percentage of rows have missing values?
#
# % of missing rows= (10,037/48,858)*100 = 20.54%
#
#
# ---
#
#
#
# **we will not be removing these rows as these are a good part of our data-(around one fiffth of our data-20%) and removing them decrease the quality of our
# data.**

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.885800e+04  4.885800e+04  48858.000000  48858.000000  48858.000000
# mean   1.902335e+07  6.763169e+07     40.728941    -73.952170    152.740309
# std    1.098289e+07  7.862389e+07      0.054528      0.046159    240.232386
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.475980e+06  7.818669e+06     40.690090    -73.983070     69.000000
# 50%    1.969114e+07  3.079133e+07     40.723070    -73.955680    106.000000
# 75%    2.915765e+07  1.074344e+08     40.763107    -73.936280    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48858.000000       48858.000000       38821.000000
# mean         7.012444          23.273098           1.373229
# std         20.019757          44.549898           1.680328
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# | Categorical Variables | Continuous Variables |
# |-----------------------|----------------------|
# | id                    | latitude             |
# | name                  | longitude            |
# | host_id               | price                |
# | host_name             | minimum_nights       |
# | neighbourhood_group   | number_of_reviews    |
# | neighbourhood         | reviews_per_month    |
# | room_type             | calculated_host_listings_count |
# |                       | availability_365     |

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
no_of_unique_neibourhoods_groups=df['neighbourhood_group'].value_counts()
print(no_of_unique_neibourhoods_groups)
print(f'\nthere are {no_of_unique_neibourhoods_groups.shape[0]} uniques neighbourhood groups')
# Out:
# Manhattan        21643
# Brooklyn         20089
# Queens            5664
# Bronx             1089
# Staten Island      373
# Name: neighbourhood_group, dtype: int64
#
# there are 5 uniques neighbourhood groups

# %%
no_of_unique_neibourhoods=df['neighbourhood'].value_counts()
print(no_of_unique_neibourhoods)
print(f'\nthere are {no_of_unique_neibourhoods.shape[0]} uniques neighbourhoods')
# Out:
# Williamsburg          3917
# Bedford-Stuyvesant    3713
# Harlem                2655
# Bushwick              2462
# Upper West Side       1969
#                       ...
# Fort Wadsworth           1
# Richmondtown             1
# New Dorp                 1
# Rossville                1
# Willowbrook              1
# Name: neighbourhood, Length: 221, dtype: int64
#
# there are 221 uniques neighbourhoods

# %% [markdown]
# in airbnb dataset-
# - every property -
#   - has a name and unique id
#   -  has a host and unique host id
# - location of property has these attributes-
#   - neighbourhood group ['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx']
#   - neighbourhood name (221 unique values)
#   - latitude and longitude
# - details of property-
#   - room type-['Private room', 'Entire home/apt', 'Shared room']
#   - price
#   - minimum nights- what are the minimum no of day i can book property for?
#   - how long it is open for booking out of 365 days in year?
# - reviews-
#   - no of reviews
#   - last reviews
#   - reviews per month
# - calculated_host_listings_count- how many properties does this host has been listed?

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %%
# Write your code to make your dataset analysis ready.
# 1.
df=df[df['price']!=0]

# %% [markdown]
# we have 11 properties whose price is zero, which is not fesible for a viable buisness.
#
# **so,we will remove the rows which contains price as zero using boolean indexing**

# %%
df[df['price']==0].shape
# Out:
# (0, 16)

# %% [markdown]
# ---

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10036
# reviews_per_month                 10036
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ---

# %%
df.sort_values(by=['neighbourhood_group', 'price'], ascending=[True, False], inplace=True)
# Out:
# <ipython-input-18-95d8cdd5fc44>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by=['neighbourhood_group', 'price'], ascending=[True, False], inplace=True)

# %% [markdown]
# we are sorting values of dataframe based on the 5 uniques neighbourhood, so that all the same neighbourhood peoperties are grouped together.
#
#
# then, these properties are sorted on 'price' column from highest price to lowest price of each neighbourhood group

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48847 entries, 24477 to 45646
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48847 non-null  int64
#  1   name                            48847 non-null  object
#  2   host_id                         48847 non-null  int64
#  3   host_name                       48847 non-null  object
#  4   neighbourhood_group             48847 non-null  object
#  5   neighbourhood                   48847 non-null  object
#  6   latitude                        48847 non-null  float64
#  7   longitude                       48847 non-null  float64
#  8   room_type                       48847 non-null  object
#  9   price                           48847 non-null  int64
#  10  minimum_nights                  48847 non-null  int64
#  11  number_of_reviews               48847 non-null  int64
# ...

# %% [markdown]
# ---

# %% [markdown]
# Also, the availability_365 column represetns the availability around the year.

# %%
df[df['availability_365']==0].shape
# Out:
# (17505, 16)

# %% [markdown]
# there are 17,505 properties whose availabilty is around zero.
# we should note that these are not None vales but only mean zero.
#
# Zero could mean different scenarieos and shouldnt be assumed None. also, they are around 35% of our data. if we reomove these,it will affect our data quality.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ### Univariate analysis

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# df.info()
sns.countplot(data=df,x='neighbourhood_group')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **to understand the distribution of no of properties in a specific neigboourhood group using count plot**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Brooklyn and manhattan have maximum no of rooms
#
# * next highest count is queens with 1/4th no of room
#
# * lowest rooms in staten island

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * there could be more no of properties in staten and queens island if there is growth in no of room booking in these states
#
# * properties in manhattan and brooklyn which have very low or no booking can be closed to optimize for profit

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# df.info()
sns.countplot(data=df,x='room_type')
# Out:
# <Axes: xlabel='room_type', ylabel='count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **to understand what is the distribution of room types**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# airbnb has most rooms of
# * home or appartment or private type.
# * Private room
#
# Shared room are very few as compared to other room types

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **we should focus more on creating room types which are more private and personalized than one which needs to be shared.**
#
#
# That means most consumers want to have the room on thier own and dont want to share it with someone else.
#
# * If the no of guests is less then priavte room
# * If more no of guests a apartment/home type room
#
# for positive buisness impact, we should focus more on home/aparmtnet type room and see if shared rooms acount for any loss or negative growth.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Chart - 4 visualization code
sns.boxplot(x=df['price']).set_xlim(0,1000)
# Out:
# (0.0, 1000.0)

# %%
df['price'].describe()
# Out:
# count    48847.000000
# mean       152.774705
# std        240.248498
# min         10.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **to unsderstand the distribution of the prices of room **

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Above, 75% of properties have prices less than or equal to 175$
#
# the highest price is 10,000$.
#
# this is a huge gap

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# a very high volume of properties has price less than 1000$
#
# this could be because of people prefer more budget freindly properties.
#
# so, for positive business impact. we should focus more on listing properties whose price is more than 200$ and less than 1000

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 5 visualization code
sns.histplot(x=df['minimum_nights']).set_xlim(0,10)
#
# Out:
# (0.0, 10.0)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %%
df['minimum_nights'].describe()
# Out:
# count    48847.000000
# mean         7.012365
# std         20.021362
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %% [markdown]
# 75% of properties have minimum nights of less than 5 night stay.
#
# So, we limit our hist plot to 10 nights in above graph to see the more precise distribution of minimum_nights variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# most properties offer minimur nights to stay is 5 nights

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# properties whose minimum_nights to stay are more than 10 nights should decrease this criteria as it will result in negaitve growth
#
# as it requires more commitment from customer than other properties and results in fewer booking.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 6 visualization code
df['number_of_reviews'].describe()
# Out:
# count    48847.000000
# mean        23.270621
# std         44.550647
# min          0.000000
# 25%          1.000000
# 50%          5.000000
# 75%         24.000000
# max        629.000000
# Name: number_of_reviews, dtype: float64

# %%
sns.boxplot(x=df['number_of_reviews'])
# Out:
# <Axes: xlabel='number_of_reviews'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to know the distribution of number of reviews for each property

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# most of the properties have no of reviews less than 25.
#
# with very few properties having very high no of reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# properties which have reviews less than 10 should focus on increasing their number of reviews.
#
# specifically from guests who have stayed at the property and but didnt rate the property.
#
# this help in building more trust with customer as they will be less skeptic about the quality of their stay and facilities before booking the stay.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 7 visualization code
#
sns.histplot(x=df['reviews_per_month'])
# Out:
# <Axes: xlabel='reviews_per_month', ylabel='Count'>

# %%
sns.histplot(x=df['reviews_per_month']).set_xlim(0,5)
# Out:
# (0.0, 5.0)

# %%
df['reviews_per_month'].describe()
# Out:
# count    38811.000000
# mean         1.373135
# std          1.680276
# min          0.010000
# 25%          0.190000
# 50%          0.720000
# 75%          2.020000
# max         58.500000
# Name: reviews_per_month, dtype: float64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to understand the distribution of continous variable of review per month as it represent how many vistors are visting that property and how they are rating it.
#
# this metric represents how frequent it is being booked.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# half of the properties(50%) are having less than 1 reviews per month

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# as we know, no of reviews is direct indicator of how frequently the property is being booked.
#
# we should take all possible measures to increase the no of reviews per onth for properties who fall below less than 1 rating per month

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 8 visualization code
sns.histplot(df['availability_365'])
# df.info()
# Out:
# <Axes: xlabel='availability_365', ylabel='Count'>

# %%
df.head(50)
# Out:
#              id                                               name    host_id  \
# 24477  19698169                            "The luxury of Comfort"  131826530
# 48282  36177241                             VJ'S 5 HOUR YACHT TOUR   23732730
# 25422  20330081         New York's Hidden Secret for luxury living  131826530
# 8521    6557289                    1 Room in a 2 Bedroom Available    7074531
# 38433  30253236                               SedaOn2 Dance Studio  140862407
# 25405  20316497                                 Luxury and comfort  131826530
# 48310  36199090           ROMANTIC SUNSET YACHT CRUISE & FIREWORKS   23732730
# 15111  12070965                        Downtown style in the Bronx   64678583
# 16607  13294137    Quiet, Secure, Clean and very Private Apartment   75030399
# 34709  27526997  Vie's NY Unique crashpad apts sleep 14, metro*...     310670
# 7018    5046189  Modern/Spacious 4BR +Tent Perfect for LARGE gr...   23732730
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Bi variate analysis

# %% [markdown]
# #### Chart - 8

# %%
sns.violinplot(x=df['neighbourhood_group'],y=df['price'])
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %%
sns.violinplot(x=df['neighbourhood_group'],y=df['price']).set_ylim(0,500)
# Out:
# (0.0, 500.0)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to compare the prices of properties in different neighbourhood groups. it inlcued comparing maximum, minimum and mean of each category
#
# **the thickness of plot represents the density or frequency of properties existing at that price**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# all properties have some outliers with very expensive properties.
#
# in the second graph which is limited for prices less than 2,000$. we can get following insights
#
# * Bronx,Brooklyn and Queens have similar thickness along y-axis where Bronx thickness is higher and Brokklyn and queens have more similar thicknes. The highest concentration for all three is at same price mark of **100$ or below**
#
#
# * Sateten Island structure of their thickness with more spreaded and evenly distributed data points.
#
#
# * Manhattan has similar structure like Staten Island but has most no of properties btw 100
# & 200 $ price range. not like Staten Island which has more smoother distribution of properties

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# to creat positive buisness impact, we should focus more on properties where the thickness/frequency of property is too much.
#
# focusing on more well spreaded property within the price range of 0-300$ will help in catering to more customer segments.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# price vs room type- numerical vs categorical
sns.violinplot(x=df['room_type'],y=df['price'])
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
sns.violinplot(x=df['room_type'],y=df['price']).set_ylim(0,1000)
# Out:
# (0.0, 1000.0)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to compare the prices of differnt room types

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# as we know from Chart 3 countplot. we known the private room type and apartment room type have highest count with shared room count at very less.
#
# apartment room type has more well distributed price range as compared to other two.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# as no of private rooms are almost same as of no of apartment type room
#
# but their prices not as well distributed as the apartment type room has.

# %% [markdown]
# #### Chart - 10

# %%
sns.scatterplot(data=df,x='number_of_reviews',y='price')
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='price'>

# %%
sns.scatterplot(data=df,x='number_of_reviews',y='price').set_ylim(0,1000)
# Out:
# (0.0, 1000.0)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to compare numerical variables -no of reviews vs price of that property

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * the properties with highest prices have least number of reviews.
#
# * the properties with lowest prices have most no of reviews

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# to increase the number of reviews for properties whose price is below 500$ and has zero or very less reviews. because this will result in more valid options for a customer to choose from by seeing more reviews from these properties.

# %% [markdown]
# ### Multi variate analysis

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
sns.barplot(data=df,x='neighbourhood_group',y='price',hue='room_type')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * on bar plot - distribution of average price of property within each neighbour hood group and each room type in that neoghbourhood

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# the average is highest for manhattan for all three room types.
#
# for lowet average prices-
# * for private rooms, it is Staten Island
# * for Entire home/apt type rooms, it is for Queens.
# * for shared rooms, it is for Brooklyn

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

sns.violinplot(data=df,x='neighbourhood_group',y='price',hue='room_type')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %%
# Chart - 12 visualization code

sns.violinplot(data=df,x='neighbourhood_group',y='price',hue='room_type').set_ylim(0,500)
# Out:
# (0.0, 500.0)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# on violin plot- distribution of the price range of properties of each nighbourhood group and each room type in that neigbourhood on violin plot

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# a we know, the number of entire home/apt type and private rooms are maximum. so we will focus on them the most-
# * for entire home/apt type rooms, the price of most properties in **bronx and queens** is less than 150$ range with similar thickkness on y axis that represent the density of properties around that price range.for **Brooklyn, Manhattan and Staten Island**, the properties with different prices are well distributed
#
#
# * for private rooms, Staten Island has highest density of properties whose price is less than 100$ while others have better distribution
#
# * for shared rooms, whose count are very less across all neighbourhoods,brooklyn has the highest density of prices less than 100$ and other have well distirbuted prices

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# for enitre home/apt type rooms, we should focus more on bronx and queens to increase properties whose prices is greater than 100 & 200$ for better distribution of prices.

# %% [markdown]
# #### Chart - 13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48847 entries, 24477 to 45646
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48847 non-null  int64
#  1   name                            48847 non-null  object
#  2   host_id                         48847 non-null  int64
#  3   host_name                       48847 non-null  object
#  4   neighbourhood_group             48847 non-null  object
#  5   neighbourhood                   48847 non-null  object
#  6   latitude                        48847 non-null  float64
#  7   longitude                       48847 non-null  float64
#  8   room_type                       48847 non-null  object
#  9   price                           48847 non-null  int64
#  10  minimum_nights                  48847 non-null  int64
#  11  number_of_reviews               48847 non-null  int64
# ...

# %%
# Chart - 13 visualization code
sns.scatterplot(data=df,y='price',x='number_of_reviews',hue='room_type')
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='price'>

# %%
# Chart - 13 visualization code
sns.scatterplot(data=df,y='price',x='number_of_reviews',hue='room_type').set_ylim(0,1000)
# Out:
# (0.0, 1000.0)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# What are the number of reviews for properties with different prices of each room type

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * for home/apartment room type, the higher the price, lower the number of reviews for it
#
# * for private room type, most properties which have higher number of reviews have low prices

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# for positive buinses impact, homer/aprtment properties with higher prices should have more reviews
#
# private rooms with higher prices should focus more on increasingn their number of reviews

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48847 entries, 24477 to 45646
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48847 non-null  int64
#  1   name                            48847 non-null  object
#  2   host_id                         48847 non-null  int64
#  3   host_name                       48847 non-null  object
#  4   neighbourhood_group             48847 non-null  object
#  5   neighbourhood                   48847 non-null  object
#  6   latitude                        48847 non-null  float64
#  7   longitude                       48847 non-null  float64
#  8   room_type                       48847 non-null  object
#  9   price                           48847 non-null  int64
#  10  minimum_nights                  48847 non-null  int64
#  11  number_of_reviews               48847 non-null  int64
# ...

# %%
# Select numerical columns
numerical_cols = ['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']
df_numerical = df[numerical_cols]

# Calculate correlations
corr = df_numerical.corr()

# Plot heatmap
# plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', cbar=True, square=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to see the corlation btw all continour variables in the dataset

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# there is slighly psotive corealtion between no_o_reviews and reviews per month. it makes sense as more the reviews more the number of reviews per month on that property.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48847 entries, 24477 to 45646
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48847 non-null  int64
#  1   name                            48847 non-null  object
#  2   host_id                         48847 non-null  int64
#  3   host_name                       48847 non-null  object
#  4   neighbourhood_group             48847 non-null  object
#  5   neighbourhood                   48847 non-null  object
#  6   latitude                        48847 non-null  float64
#  7   longitude                       48847 non-null  float64
#  8   room_type                       48847 non-null  object
#  9   price                           48847 non-null  int64
#  10  minimum_nights                  48847 non-null  int64
#  11  number_of_reviews               48847 non-null  int64
# ...

# %%
# Pair Plot visualization code
sns.pairplot(data=df,vars=['price','minimum_nights','number_of_reviews'],hue='neighbourhood_group')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# * The client should focus on expanding their presence in Staten Island and Queens, as these areas have the lowest number of rooms and could have potential demand for more listings.
# * The client should also consider closing or relocating some of their properties in Manhattan and Brooklyn that have very low or no bookings, as these areas have the highest number of rooms and could have oversupply or high competition.
# * The client should offer more home/apartment or private room types, as these are the most preferred by the customers. They should also avoid shared room types, as these are the least preferred and could have negative growth.
# * The client should optimize their pricing strategy to attract more customers who are looking for budget-friendly properties. They should focus on listing properties whose price is more than 200$ and less than 1000, as these are the most common price ranges in the market.
# * The client should reduce their minimum nights requirement for some of their properties, especially those that have more than 10 nights. This could increase their booking rate and customer satisfaction, as it would require less commitment from the customers and offer more flexibility.
# * The client should encourage their guests to leave more reviews, especially those who have stayed at the property but did not rate it. This could help them build more trust and credibility with potential customers, as they would be able to see the quality of the stay and the facilities before booking.

# %% [markdown]
# * Optimize the room types and prices to match the customer preferences and demand. Offer more private and personalized rooms, such as home/apartment types, and avoid shared rooms. List more properties with prices between $200 and $1000, and address the price gap between low-end and high-end properties.
# * Reduce the minimum nights stay requirement for some properties, especially those with more than 10 nights, to increase the booking rate and customer satisfaction.
# * Encourage more reviews from the guests, especially those who have stayed but did not rate the property, to build trust and credibility with potential customers.
# * Focus on expanding the number of properties in Staten Island and Queens, as these areas have the lowest number of rooms and could have potential demand for more listings. Also, consider closing or relocating some properties in Manhattan and Brooklyn that have very low or no bookings, as these areas have the highest number of rooms and could have oversupply or high competition.
# * Develop targeted marketing strategies for neighborhoods with high property density and positive pricing structures, such as Bronx and Queens for entire home/apartment types. Pay attention to neighborhoods where the average price is higher for specific room types, such as Manhattan, Staten Island, Queens, and Brooklyn.
# * Consider promotions or incentives to increase the number of reviews for properties priced below $500, enhancing the range of options for customers and increasing property visibility.
# Investigate areas with lower property counts and explore the potential for growth, as increasing the number of properties may lead to increased business.
# * Collect and analyze customer feedback to understand specific needs and preferences. Continuously iterate and improve business strategies based on changing market dynamics and customer demands.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
